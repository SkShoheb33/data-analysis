# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %%
data = pd.read_csv('C:\\Users\\exam2\\Downloads\\movies_1_.csv')
data
# Out:
#                            Title  US Gross Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083          146083           NaN
# 1         First Love, Last Rites     10876           10876           NaN
# 2     I Married a Strange Person    203134          203134           NaN
# 3           Let's Talk About Sex    373615          373615           NaN
# 4                           Slam   1009819         1087521           NaN
# ...                          ...       ...             ...           ...
# 3196  Zack and Miri Make a Porno  31452765        36851125    21240321.0
# 3197                      Zodiac  33080084        83080084    20983030.0
# 3198                        Zoom  11989328        12506188     6679409.0
# 3199         The Legend of Zorro  45575336       141475336           NaN
# 3200           The Mask of Zorro  93828745       233700000           NaN
#
#       Production Budget Release Date MPAA Rating  Running Time (min)  \
# ...

# %%
data = pd.read_csv('C:\\Users\\exam2\\Downloads\\movies_1_.csv')

# data

# %%
#1. 	 (i). Find out the no of movies released in every month of the year 1995.
data.drop(data[data['Release Date']=='TBD'].index,axis=0,inplace=True)

data["Release Date"]=data['Release Date'].apply(lambda x:pd.to_datetime(x))

# data

# %%
data = data[data['Release Date'].apply(lambda x:x.year)==1995]
data.groupby(pd.Grouper(key='Release Date',axis=0,freq='m'))['Title'].count()
# Out:
# Release Date
# 1995-01-31     3
# 1995-02-28     2
# 1995-03-31     3
# 1995-04-30     5
# 1995-05-31     6
# 1995-06-30     7
# 1995-07-31     8
# 1995-08-31     7
# 1995-09-30     4
# 1995-10-31     8
# 1995-11-30     7
# 1995-12-31    13
# Freq: M, Name: Title, dtype: int64

# %%
#(ii). Find out the no. of movies released in every year from 1990 to 1998.
data = data[data['Release Date'].apply(lambda x:x.year).between(1990,1998)]
data.groupby(pd.Grouper(key='Release Date',axis=0,freq='y'))['Title'].count()
# Out:
# Release Date
# 1990-12-31     28
# 1991-12-31     33
# 1992-12-31     28
# 1993-12-31     39
# 1994-12-31     52
# 1995-12-31     73
# 1996-12-31     99
# 1997-12-31     97
# 1998-12-31    144
# Freq: A-DEC, Name: Title, dtype: int64

# %%
# 2.	(i). Find no. of movies released under each genre given in the database.
key = 'Major Genre'
data.groupby([key])['Title'].count()
# Out:
# Major Genre
# Action               115
# Adventure             47
# Black Comedy          10
# Comedy               128
# Documentary            1
# Drama                156
# Horror                34
# Musical                6
# Romantic Comedy       21
# Thriller/Suspense     43
# Western                5
# Name: Title, dtype: int64

# %%
#(ii). Find the movies under each genre with 1MDB rating >7 and rotten tomatoes rating > 60.

data[(data['IMDB Rating']>7) & (data['Rotten Tomatoes Rating']>60)].groupby(['Major Genre'])['Title'].count()
# Out:
# Major Genre
# Action               15
# Adventure             7
# Black Comedy          1
# Comedy                9
# Documentary           1
# Drama                59
# Horror                1
# Romantic Comedy       7
# Thriller/Suspense    11
# Western               2
# Name: Title, dtype: int64

# %%
data = data.fillna(0)

# %%
# 3.	(i). Find the movies released under each fiction with each director in the ascending order of release dates.
d = data[data['Creative Type'].apply(lambda x : 'Fiction' in str(x))].groupby(['Director','Creative Type']).first()
# d.sort_values('Release Date',inplace=True)
d.groupby(['Director','Creative Type']).first().sort_values('Release Date')
# d.groupby(['Director','Creative Type'])['Release Date'].first()
# Out:
#                                                                Title  \
# Director                 Creative Type
# Jeff "King Jeff" Hollins Contemporary Fiction                   Bang
# Neil LaBute              Contemporary Fiction  In the Company of Men
# Charles Martin Smith     Kids Fiction                        Air Bud
# Oliver Stone             Contemporary Fiction             Talk Radio
# 0                        Kids Fiction           Fantasia 2000 (IMAX)
# ...                                                              ...
# Kevin Costner            Historical Fiction       Dances with Wolves
# Peter Billingsley        Contemporary Fiction        Couples Retreat
# Thomas Vinterberg        Contemporary Fiction                 Festen
# 0                        Contemporary Fiction                   Slam
# Robert Wise              Historical Fiction       The Sound of Music
#
#                                                 US Gross Worldwide Gross  \
# ...

# %%
# (ii). Find movies released under each distributor in the order of genre and director.
pd.set_option('display.max_rows',None)
data.groupby(['Distributor','Major Genre','Director'])['Title'].count()
# Out:
# Distributor                        Major Genre          Director
# 0                                  0                    0                              106
#                                                         Alfred Hitchcock                 2
#                                                         Billy Wilder                     2
#                                                         Blake Edwards                    1
#                                                         Bob Fosse                        1
#                                                         Bob Rafelson                     1
#                                                         Brad Anderson                    1
#                                                         Brian De Palma                   1
#                                                         David Lynch                      2
#                                                         Elia Kazan                       2
# ...

# %%
# 4.	(i). Find the movies released world-wide and find out the revenue received world-wide other than US with their ratings.
data[(data['Worldwide Gross'].astype(int)-data['US Gross'].astype(int))>0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3292/3021711505.py in <module>
#       1 # 4.    (i). Find the movies released world-wide and find out the revenue received world-wide other than US with their ratings.
# ----> 2 data[(data['Worldwide Gross'].astype(int)-data['US Gross'].astype(int))>0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
# ...

# %%
data.columns
# Out:
# Index(['Title', 'US Gross', 'Worldwide Gross', 'US DVD Sales',
#        'Production Budget', 'Release Date', 'MPAA Rating',
#        'Running Time (min)', 'Distributor', 'Source', 'Major Genre',
#        'Creative Type', 'Director', 'Rotten Tomatoes Rating', 'IMDB Rating',
#        'IMDB Votes'],
#       dtype='object')
